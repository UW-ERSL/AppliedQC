# %% [markdown]
# # Chapter 7 Solutions: Landmark Algorithms
#
# ---
#
# **📘 INSTRUCTOR NOTE:**
# - Solutions use the same utilities as the main textbook notebooks
# - Students should work through the main chapter notebook first
# - Some solutions may still be in development (marked as WIP)
#
# ---

# %%
# Solutions Setup
import numpy as np
import matplotlib.pyplot as plt
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.circuit.library import UnitaryGate, MCXGate
from qiskit.quantum_info import Statevector, Operator
# Add utilities to path
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent ))

from Chapter08_QuantumGates_functions import simulate_statevector, simulate_measurements, plot_measurement_results #type: ignore
from Chapter11_LandmarkAlgorithms_functions import createPhaseInversionCircuit #type: ignore
print('Solutions setup complete!')
# Out:
# Solutions setup complete!

# %% [markdown]
# ## Phase kickback

# %%
circuit = QuantumCircuit(2)  
circuit.x(0)
circuit.h(0)
circuit.barrier()
circuit.cx(1,0,ctrl_state=0)
circuit.barrier()
circuit.h(0)
circuit.x(0)
display(circuit.draw('mpl'))
psi = Statevector(circuit)
display(psi.draw('latex'))
# Out:
# $$- |00\rangle$$

# %% [markdown]
# ## Grover Algorithm

# %% [markdown]
# ### U_f operator

# %%
U_f, n = createPhaseInversionCircuit()
