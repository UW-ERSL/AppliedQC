# %% [markdown]
# # Chapter 2 Solutions:

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
from Chapter02_QuantumSoftware_functions import secretBitStringFunction
print('Solutions setup complete!')
# Out:
# Solutions setup complete!

# %%
def BV_classical(N):
    s = N*[None] # initialize
    for i in range(N):
        x = N*[0] # initialize every loop
        x[i] = 1
        bit = secretBitStringFunction(x)
        s[i] = bit
    return s

N = 5
s = BV_classical(N)
print("Classical: The secret bit string",s)
# Out:
# Classical: The secret bit string [1, 1, 0, 1, 0]
